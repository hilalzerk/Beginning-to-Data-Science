# %% [markdown]
# # 6.1. Oluşturma

# %%
person = {
    "name": "Hilal",
    "role": "Data Learner"
}

# %%
person["name"]  # Değere erişim
# Out:
# 'Hilal'

# %%
person["role"]
# Out:
# 'Data Learner'

# %%
person["role"] = "Data Analyst" # Değer güncelleme

# %%
person["role"]
# Out:
# 'Data Analyst'

# %%
person["country"] = "Turkey"  # Key değeri ekleme

# %%
person
# Out:
# {'name': 'Hilal', 'role': 'Data Analyst', 'country': 'Turkey'}

# %%
notes = [80,72,95]
name = ["Deniz", "Ege", "Gizem"]

# %%
name[0]
# Out:
# 'Deniz'

# %%
notes[0]
# Out:
# 80

# %%
print(name[0], "named student note is", notes[0])
# Out:
# Deniz named student note is 80

# %%
notes = [80,72,95]
name = ["Deniz", "Ege", "Gizem"]
no = [703, 408, 690]

# %%
students = {"Deniz": {"note":80, "student_no":703}, "Ege":{"note":72, "student_no":408}, "Gizem": {"note":95, "student_no":690}}

# %%
students["Ege"]
# Out:
# {'note': 72, 'student_no': 408}

# %%
students["Ege"]["student_no"]
# Out:
# 408

# %%
students["Ege"]["note"]
# Out:
# 72

# %%
notes["Mert"] # checking for element which is not exist
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 notes["Mert"]
#
# TypeError: list indices must be integers or slices, not str

# %%
notes = {'Deniz': 80, 'Ege': 72, 'Gizem': 95}

# %%
notes["Ege"] = notes["Ege"] + 5

# %%
notes
# Out:
# {'Deniz': 80, 'Ege': 77, 'Gizem': 95}

# %%
notes
# Out:
# {'Deniz': 80, 'Ege': 77, 'Gizem': 95}

# %%
len(notes)
# Out:
# 3

# %%
notes["Mert"] = 58 
notes
# Out:
# {'Deniz': 80, 'Ege': 77, 'Gizem': 95, 'Mert': 58}

# %%
del notes["Mert"]
notes
# Out:
# {'Deniz': 80, 'Ege': 77, 'Gizem': 95}

# %%
"Mert" in notes
# Out:
# False

# %%
"Ege" in notes
# Out:
# True
