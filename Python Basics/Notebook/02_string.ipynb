# %% [markdown]
# # 1. String (str)

# %% [markdown]
# ## 1.1. Indexing

# %%
text = "Data Science"
text[0]
# Out:
# 'D'

# %%
text = "Data Science"
text[5]
# Out:
# 'S'

# %% [markdown]
# ## 1.2. Slicing

# %%
text = "Data Science"
text[5:]
# Out:
# 'Science'

# %%
text[0:3]
# Out:
# 'Dat'

# %% [markdown]
# ## 1.3. Length (len)

# %%
text = "Data Science"
len(text)
# Out:
# 12

# %% [markdown]
# ## 1.4. Converting to Lowercase / Uppercase

# %%
text = "Data Science"
text.upper()
# Out:
# 'DATA SCIENCE'

# %%
text.lower()
# Out:
# 'data science'

# %% [markdown]
# ## 1.5. Removing Whitespace

# %%
name = "  Data Science  "
name.strip()
# Out:
# 'Data Science'

# %% [markdown]
# ## 1.6. Split

# %%
line = "Ankara,Turkey,2025"
line.split(",")
# Out:
# ['Ankara', 'Turkey', '2025']

# %% [markdown]
# ## 1.7. Birleştirme (join)

# %%
words = ["Data", "Science"]
" ".join(words)
# Out:
# 'Data Science'

# %% [markdown]
# ## 1.7.Join

# %%
words = ["Data", "Science"]
" ".join(words)
# Out:
# 'Data Science'
