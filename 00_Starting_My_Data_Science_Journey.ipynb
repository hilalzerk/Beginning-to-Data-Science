# %%
print("Today I begin my journey into data science by building a strong foundation in Python. // 13.10.2025")
# Out:
# Today I begin my journey into data science by building a strong foundation in Python. // 13.10.2025
